# %%
import numpy as np

from PIL import Image

import matplotlib.pyplot as plt

# %%
path_gray = './gray_img.jpg'

image_pil_gray = Image.open(path_gray)
image_gray = np.array(image_pil_gray)

# %%
image_gray.shape
# Out:
# (1065, 1920, 3)

# %%
np.min(image_gray), np.max(image_gray)
# Out:
# (0, 255)

# %%
plt.imshow(image_gray)

# %%
path_color = './color_img.jpg'

image_pil_color = Image.open(path_color)
image_color = np.array(image_pil_color)

# %%
image_color.shape
# Out:
# (1280, 1920, 3)

# %%
np.min(image_color), np.max(image_color)
# Out:
# (0, 255)

# %%
plt.imshow(image_color)

# %%
image_pil_color_to_gray = Image.open(path_color).convert('L')
image_bw = np.array(image_pil_color_to_gray)

# %%
plt.imshow(image_bw, 'gray')

# %%
image_bw.shape
# Out:
# (1280, 1920)

# %%
image_pil_gray_to_gray = Image.open(path_gray).convert('L')
image_bw2 = np.array(image_pil_gray_to_gray)

# %%
plt.imshow(image_bw2, 'gray')

# %%
image_bw2.shape
# Out:
# (1065, 1920)

# %%
# !pip install opencv-python
# Out:
# ...
#      --------------------------------------- 35.6/35.6 MB 54.7 MB/s eta 0:00:00
# ...

# %%
import cv2

# %%
cv2.imwrite('./img_color.jpg', image_bw2)
# Out:
# True

# %%
path_mnist = './mnist_7.jpg'

image_pil_mnist = Image.open(path_mnist)
image_mnist = np.array(image_pil_mnist)

# %%
image_mnist.shape
# Out:
# (28, 28)

# %%
np.min(image_mnist), np.max(image_mnist)
# Out:
# (0, 255)

# %%
plt.imshow(image_mnist)

# %%
plt.imshow(y)

# %%
y = np.expand_dims(image_mnist, axis = -1)

# %%
y.shape
# Out:
# (28, 28, 1)

# %%
B = image_mnist
R = image_mnist
G = image_mnist

# %%
merged = cv2.merge([B, R, G])

# %%
merged.shape
# Out:
# (28, 28, 3)

# %%
plt.imshow(merged)

# %%
cv2.imwrite('./merged.jpg', merged)
# Out:
# True
